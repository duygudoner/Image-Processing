# %%
import os
os.getcwd()
os.listdir()
# Out:
# ['istanbul.jpg', 'istanbulGray.jpg']

# %%
os.chdir('C:\\Users\\duygu\\Desktop\\görüntü işleme\\2.hafta')

# %%
my_list=[9,3,5,6,2,3,6]

# %%
my_list
# Out:
# [9, 3, 5, 6, 2, 3, 6]

# %%
for i in my_list:
    print(i)
# Out:
# 9
# 3
# 5
# 6
# 2
# 3
# 6

# %%
def my_function_1(my_list=[9,3,5,6,2,3,6]):
    #my_list=[9,3,5,6,2,3,6]
    for i in range(len(my_list)):
        #print(i,my_list[i])
        my_list[i]=my_list[i]+1
    print(my_list)
#my_function_1(['bir',5,7,6,41,12,33])
my_function_1()
# Out:
# [10, 4, 6, 7, 3, 4, 7]

# %%
import numpy as np
my_list_1=np.array(list([9,3,5,6,2,3,6]))  #ndarray
my_list_1
# Out:
# array([9, 3, 5, 6, 2, 3, 6])

# %%
my_list_1+1
# Out:
# array([10,  4,  6,  7,  3,  4,  7])

# %%
def my_function_2(my_array=np.array(list([9,3,5,6,2,3,6]))):
    return my_array+10
my_function_2()
# Out:
# array([19, 13, 15, 16, 12, 13, 16])

# %%
import matplotlib.pyplot as plt

# %%
im_1=plt.imread('istanbul.jpg')

# %%
plt.imshow(im_1)
plt.show()

# %%
im_1.ndim, im_1.shape
# Out:
# (3, (344, 620, 3))

# %%
m,n,p=im_1.shape
im_2=np.zeros((m,n,3),dtype=int)
m,n,im_2.shape
for m in range(im_1.shape[0]):
    for n in range(im_1.shape[1]):
        im_2[m,n,0]=im_1[m,n,0]-25   #R bantını 25 eksiltiyor (+ yı da dene)
        im_2[m,n,1]=im_1[m,n,0]
        im_2[m,n,2]=im_1[m,n,0]
plt.imshow(im_2)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def my_function_3(im_100,s):
    im_1=im_100
    m,n,p=im_1.shape
    im_2=np.zeros((m,n,3),dtype=int)
    m,n,im_2.shape
    for m in range(im_1.shape[0]):
        for n in range(im_1.shape[1]):
            im_2[m,n,0]=im_1[m,n,0]-s   #R bantını 25 eksiltiyor (+ yı da dene)
            im_2[m,n,1]=im_1[m,n,0]
            im_2[m,n,2]=im_1[m,n,0]
    return im_100

# %%
def my_function_4(im_500):
    m,n,p=im_500.shape
    new_m=int(m/2)
    new_n=int(n/2)
    im_600=np.zeros((new_m,new_n),dtype=int)
    
    for m in range(new_m):
        for n in range(new_n):
            s0=(im_500[m*2,n*2,0]+im_500[m*2,n*2,1]+im_500[m*2,n*2,2])/3 #bulunulan piksel
            im_600[m,n]=int(s0)
    return im_600

# %%
im_6=my_function_4(im_1)
plt.imshow(im_6,cmap='gray')
plt.show()
plt.imsave('istanbulGray.jpg',im_6,cmap='gray')
# Out:
# C:\Users\duygu\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in ubyte_scalars
#   if __name__ == '__main__':

# %%
im_1.shape
# Out:
# (344, 620, 3)

# %%
im_6.shape
# Out:
# (172, 310)

# %%
def my_scale(im_7):
    m,n,p=im_7.shape
    new_m=int(m/2)
    new_n=int(n/2)
    im_8=np.zeros((new_m,new_n,3),dtype=int)
    for m in range(new_m):
        for n in range(new_n):
            im_8[m,n,0]=int(im_7[m*2,n*2,0])
            im_8[m,n,1]=int(im_7[m*2,n*2,1])
            im_8[m,n,2]=int(im_7[m*2,n*2,2])
    return im_8

# %%
plt.imshow(im_1)

# %%
im_10=my_scale(im_1)
plt.imshow(im_10)

# %%
im_100=my_scale(im_10)
plt.imshow(im_100)
